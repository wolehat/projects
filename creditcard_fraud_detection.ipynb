# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fraud = pd.read_csv('creditcard.csv')

# %%
fraud.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
sns.countplot(fraud['Class'], data=fraud, label = 'counts')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(x= 'V8', y= 'V9', hue = 'Class', data = fraud)

# %%
fraud.corr()
# Out:
#             Time            V1            V2  ...           V28    Amount     Class
# Time    1.000000  1.173963e-01 -1.059333e-02  ... -9.412688e-03 -0.010596 -0.012323
# V1      0.117396  1.000000e+00  4.697350e-17  ...  9.820892e-16 -0.227709 -0.101347
# V2     -0.010593  4.697350e-17  1.000000e+00  ... -3.676415e-16 -0.531409  0.091289
# V3     -0.419618 -1.424390e-15  2.512175e-16  ...  7.726948e-16 -0.210880 -0.192961
# V4     -0.105260  1.755316e-17 -1.126388e-16  ... -5.863664e-17  0.098732  0.133447
# V5      0.173072  6.391162e-17 -2.039868e-16  ... -3.299167e-16 -0.386356 -0.094974
# V6     -0.063016  2.398071e-16  5.024680e-16  ...  4.813155e-16  0.215981 -0.043643
# V7      0.084714  1.991550e-15  3.966486e-16  ... -6.836764e-17  0.397311 -0.187257
# V8     -0.036949 -9.490675e-17 -4.413984e-17  ... -4.484325e-16 -0.103079  0.019875
# V9     -0.008660  2.169581e-16 -5.728718e-17  ...  9.146779e-16 -0.044246 -0.097733
# ...

# %%
plt.figure(figsize=[30,10])
sns.heatmap(fraud.corr(), annot=True)

# %%
fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
X= fraud.drop('Class', axis=1)
X
# Out:
#             Time         V1         V2  ...       V27       V28  Amount
# 0            0.0  -1.359807  -0.072781  ...  0.133558 -0.021053  149.62
# 1            0.0   1.191857   0.266151  ... -0.008983  0.014724    2.69
# 2            1.0  -1.358354  -1.340163  ... -0.055353 -0.059752  378.66
# 3            1.0  -0.966272  -0.185226  ...  0.062723  0.061458  123.50
# 4            2.0  -1.158233   0.877737  ...  0.219422  0.215153   69.99
# ...          ...        ...        ...  ...       ...       ...     ...
# 284802  172786.0 -11.881118  10.071785  ...  0.943651  0.823731    0.77
# 284803  172787.0  -0.732789  -0.055080  ...  0.068472 -0.053527   24.79
# 284804  172788.0   1.919565  -0.301254  ...  0.004455 -0.026561   67.88
# 284805  172788.0  -0.240440   0.530483  ...  0.108821  0.104533   10.00
# 284806  172792.0  -0.533413  -0.189733  ... -0.002415  0.013649  217.00
#
# [284807 rows x 30 columns]

# %%
y=fraud['Class']

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64

# %%
non_fraud = fraud[fraud['Class']==0]

# %%
fraud_cases = fraud[fraud['Class']==1]

# %%
fraud_cases
# Out:
#             Time        V1        V2  ...       V28  Amount  Class
# 541        406.0 -2.312227  1.951992  ... -0.143276    0.00      1
# 623        472.0 -3.043541 -3.157307  ...  0.035764  529.00      1
# 4920      4462.0 -2.303350  1.759247  ... -0.153029  239.93      1
# 6108      6986.0 -4.397974  1.358367  ...  0.849573   59.00      1
# 6329      7519.0  1.234235  3.019740  ...  0.146793    1.00      1
# ...          ...       ...       ...  ...       ...     ...    ...
# 279863  169142.0 -1.927883  1.125653  ...  0.147968  390.00      1
# 280143  169347.0  1.378559  1.289381  ...  0.186637    0.76      1
# 280149  169351.0 -0.676143  1.126366  ...  0.194361   77.89      1
# 281144  169966.0 -3.113832  0.585864  ... -0.253700  245.00      1
# 281674  170348.0  1.991976  0.158476  ... -0.015309   42.53      1
#
# [492 rows x 31 columns]

# %%
column_headers = fraud.columns.values

# %%
# kernel density estimation (KDE) is a non-parametric way to estimate the probability density function of a random variable.
i = 1

fig, ax = plt.subplots(8,4,figsize=(18,30))
for column_header in column_headers:    
    plt.subplot(8,4,i)
    sns.kdeplot(fraud_cases[column_header], bw = 0.4, label = "Fraud", shade=True, color="r", linestyle="--")
    sns.kdeplot(non_fraud[column_header], bw = 0.4, label = "Non Fraud", shade=True, color= "y", linestyle=":")
    plt.title(column_header, fontsize=12)
    i = i + 1
plt.show();
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.4 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.4 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.4 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
fraud['Amount_norm']=sc.fit_transform(fraud['Amount'].values.reshape(-1,1))

# %%
fraud = fraud.drop(['Amount'], axis = 1)

# %%
fraud.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Class',
#        'Amount_norm'],
#       dtype='object')

# %%
X=fraud.drop(['Class'], axis=1)

# %%
y=fraud.Class

# %%
X
# Out:
#             Time         V1         V2  ...       V27       V28  Amount_norm
# 0            0.0  -1.359807  -0.072781  ...  0.133558 -0.021053     0.244964
# 1            0.0   1.191857   0.266151  ... -0.008983  0.014724    -0.342475
# 2            1.0  -1.358354  -1.340163  ... -0.055353 -0.059752     1.160686
# 3            1.0  -0.966272  -0.185226  ...  0.062723  0.061458     0.140534
# 4            2.0  -1.158233   0.877737  ...  0.219422  0.215153    -0.073403
# ...          ...        ...        ...  ...       ...       ...          ...
# 284802  172786.0 -11.881118  10.071785  ...  0.943651  0.823731    -0.350151
# 284803  172787.0  -0.732789  -0.055080  ...  0.068472 -0.053527    -0.254117
# 284804  172788.0   1.919565  -0.301254  ...  0.004455 -0.026561    -0.081839
# 284805  172788.0  -0.240440   0.530483  ...  0.108821  0.104533    -0.313249
# 284806  172792.0  -0.533413  -0.189733  ... -0.002415  0.013649     0.514355
#
# [284807 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape
# Out:
# (227845, 30)

# %%
y_train.shape
# Out:
# (227845,)

# %%
X_test.shape
# Out:
# (56962, 30)

# %%
y_test.shape
# Out:
# (56962,)
